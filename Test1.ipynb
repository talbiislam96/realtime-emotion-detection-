# %%
import cv2

# %%
img = cv2.imread('hap.jpg')

# %%
import matplotlib.pyplot as plt

# %%
from deepface import DeepFace
# Out:
# Using TensorFlow backend.

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:13<00:00,  3.44s/it]

# %%
predictions
# Out:
# {'emotion': {'angry': 0.0013797493833619735,
#   'disgust': 4.916915085056837e-09,
#   'fear': 0.005209170868864223,
#   'happy': 91.88278865115575,
#   'sad': 0.0038062002653924906,
#   'surprise': 0.004447086295335109,
#   'neutral': 8.102369791410553},
#  'dominant_emotion': 'happy',
#  'age': 26.524551595087896,
#  'gender': 'Man',
#  'race': {'asian': 0.11246097274124622,
#   'indian': 7.269028574228287,
#   'black': 0.018298304348718375,
#   'white': 11.361188441514969,
#   'middle eastern': 67.88069009780884,
#   'latino hispanic': 13.358336687088013},
#  'dominant_race': 'middle eastern'}

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiscale(gray,1.1,4)
#Draw rectangle around faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-05e77525ea93> in <module>
#       1 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# ----> 2 faces = faceCascade.detectMultiscale(gray,1.1,4)
#       3 #Draw rectangle around faces
#       4 for (x, y, w, h) in faces:
#       5     cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)
#
# AttributeError: 'cv2.CascadeClassifier' object has no attribute 'detectMultiscale'

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
#Draw a rectangle around faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
#use putText() method for inserting text of in the video
cv2.putText(img,
            predictions['dominant_emotion'],
            (0,50),
            font, 1,
            (0, 0, 255),
            2,
            cv2.LINE_4
           );

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img2 = cv2.imread('sad.jpg')

# %%
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img2)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:14<00:00,  3.72s/it]

# %%
predictionq ['dominant_emotion']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-d9fe1c21ec26> in <module>
# ----> 1 predictionq ['dominant_emotion']
#
# NameError: name 'predictionq' is not defined

# %%
predictions ['dominant_emotion']
# Out:
# 'fear'

# %%
gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiscale(gray,1.1,4)
#Draw rectangle around faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-d12498cecfd7> in <module>
#       1 gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
# ----> 2 faces = faceCascade.detectMultiscale(gray,1.1,4)
#       3 #Draw rectangle around faces
#       4 for (x, y, w, h) in faces:
#       5     cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)
#
# AttributeError: 'cv2.CascadeClassifier' object has no attribute 'detectMultiscale'

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
#Draw rectangle around faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

# %%
gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
#Draw rectangle around faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

# %%
gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
#Draw rectangle around faces
for (x, y, w, h) in faces:
    cv2.rectangle(img2, (x,y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

# %%
#Real time video demo for face emotion recognition

# %%
import cv2
from deepface import DeepFace
faceCascade = cv2.CascadeClassifier(cv2.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
import cv2
from deepface import DeepFace
faceCascade = cv2.CascadeClassifier(cv2.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.videoCapture(1)
#check videocam is opened correctly
if not cap.isOpened():
    cap= cv2.VideoCapture(0)
if not   cap.isOpened():
    raise IOError("cannot open webcam")
    
while True :
    ret,frame = cap.read()#read one image from video
    result = DeepFace.analyze(frame, actions=['emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    for (x, y, w, h) in faces:
        cv2.rectangle(img2, (x,y), (x+w, y+h), (0, 255, 0), 2)
   
    font = cv2.FONT_HERSHEY_SIMPLEX 
    cv2.putText(img,
            predictions['dominant_emotion'],
            (50,50),
            font, 3,
            (0, 0, 255),
            2,
            cv2.LINE_4
           );
    cv2.imshow('original video', frame)
    
    if cv2.waitkey(2) & 0xFF('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-d1651b04bca9> in <module>
#       2 from deepface import DeepFace
#       3 faceCascade = cv2.CascadeClassifier(cv2.haarcascades + 'haarcascade_frontalface_default.xml')
# ----> 4 cap = cv2.videoCapture(1)
#       5 #check videocam is opened correctly
#       6 if not cap.isOpened():
#
# AttributeError: module 'cv2.cv2' has no attribute 'videoCapture'

# %%
import cv2
from deepface import DeepFace
faceCascade = cv2.CascadeClassifier(cv2.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(1)
#check videocam is opened correctly
if not cap.isOpened():
    cap= cv2.VideoCapture(0)
if not   cap.isOpened():
    raise IOError("cannot open webcam")
    
while True :
    ret,frame = cap.read()#read one image from video
    result = DeepFace.analyze(frame, actions=['emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    for (x, y, w, h) in faces:
        cv2.rectangle(img2, (x,y), (x+w, y+h), (0, 255, 0), 2)
   
    font = cv2.FONT_HERSHEY_SIMPLEX 
    cv2.putText(img,
            predictions['dominant_emotion'],
            (50,50),
            font, 3,
            (0, 0, 255),
            2,
            cv2.LINE_4
           );
    cv2.imshow('original video', frame)
    
    if cv2.waitkey(2) & 0xFF('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-156702f11915> in <module>
#      11 while True :
#      12     ret,frame = cap.read()#read one image from video
# ---> 13     result = DeepFace.analyze(frame, actions=['emotion'])
#      14
#      15     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#
# ~\anaconda34\envs\mvision\lib\site-packages\deepface\DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend)
#     422                         if action == 'emotion':
#     423                                 emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
# --> 424                                 img = functions.preprocess_face(img = img_path, target_size = (48, 48), grayscale = True, enforce_detection = enforce_detection, detector_backend = detector_backend)
#     425
#     426                                 emotion_predictions = emotion_model.predict(img)[0,:]
#
# ~\anaconda34\envs\mvision\lib\site-packages\deepface\commons\functions.py in preprocess_face(img, target_size, grayscale, enforce_detection, detector_backend)
#     453         base_img = img.copy()
#     454
# --> 455         img = detect_face(img = img, detector_backend = detector_backend, grayscale = grayscale, enforce_detection = enforce_detection)
#     456
#     457         #--------------------------
#
# ~\anaconda34\envs\mvision\lib\site-packages\deepface\commons\functions.py in detect_face(img, detector_backend, grayscale, enforce_detection)
#     160
#     161                         else:
# --> 162                                 raise ValueError("Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.")
#     163
#     164         elif detector_backend == 'ssd':
#
# ValueError: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.

# %%
import cv2
from deepface import DeepFace
faceCascade = cv2.CascadeClassifier(cv2.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(1)
#check videocam is opened correctly
if not cap.isOpened():
    cap= cv2.VideoCapture(0)
if not   cap.isOpened():
    raise IOError("cannot open webcam")
    
while True :
    ret,frame = cap.read()#read one image from video
    result = DeepFace.analyze(frame, actions = ['emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    for (x, y, w, h) in faces:
        cv2.rectangle(img2, (x,y), (x+w, y+h), (0, 255, 0), 2)
   
    font = cv2.FONT_HERSHEY_SIMPLEX 
    cv2.putText(img,
            predictions['dominant_emotion'],
            (50,50),
            font, 3,
            (0, 0, 255),
            2,
            cv2.LINE_4
           );
    cv2.imshow('original video', frame)
    
    if cv2.waitkey(2) & 0xFF('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-8596b8cb038e> in <module>
#      29     cv2.imshow('original video', frame)
#      30
# ---> 31     if cv2.waitkey(2) & 0xFF('q'):
#      32         break
#      33
#
# AttributeError: module 'cv2.cv2' has no attribute 'waitkey'

# %%
import cv2
from deepface import DeepFace
faceCascade = cv2.CascadeClassifier(cv2.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(1)
#check videocam is opened correctly
if not cap.isOpened():
    cap= cv2.VideoCapture(0)
if not   cap.isOpened():
    raise IOError("cannot open webcam")
    
while True :
    ret,frame = cap.read()#read one image from video
    result = DeepFace.analyze(frame, actions = ['emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    for (x, y, w, h) in faces:
        cv2.rectangle(img2, (x,y), (x+w, y+h), (0, 255, 0), 2)
   
    font = cv2.FONT_HERSHEY_SIMPLEX 
    cv2.putText(img,
            predictions['dominant_emotion'],
            (50,50),
            font, 3,
            (0, 0, 255),
            2,
            cv2.LINE_4
           );
    cv2.imshow('original video', frame)
    
    if cv2.waitKey(2) & 0xFF('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-b0b33cb0d93a> in <module>
#      29     cv2.imshow('original video', frame)
#      30
# ---> 31     if cv2.waitKey(2) & 0xFF('q'):
#      32         break
#      33
#
# TypeError: 'int' object is not callable

# %%
import cv2
from deepface import DeepFace
faceCascade = cv2.CascadeClassifier(cv2.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(1)
#check videocam is opened correctly
if not cap.isOpened():
    cap= cv2.VideoCapture(0)
if not   cap.isOpened():
    raise IOError("cannot open webcam")
    
while True :
    ret,frame = cap.read()#read one image from video
    result = DeepFace.analyze(frame, actions = ['emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    for (x, y, w, h) in faces:
        cv2.rectangle(img2, (x,y), (x+w, y+h), (0, 255, 0), 2)
   
    font = cv2.FONT_HERSHEY_SIMPLEX 
    cv2.putText(img,
            predictions['dominant_emotion'],
            (50,50),
            font, 3,
            (0, 0, 255),
            2,
            cv2.LINE_4
           );
    cv2.imshow('original video', frame)
    
    if cv2.waitkey(2) & 0xFF == ord('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-3b2a2fe6cb78> in <module>
#      29     cv2.imshow('original video', frame)
#      30
# ---> 31     if cv2.waitkey(2) & 0xFF == ord('q'):
#      32         break
#      33
#
# AttributeError: module 'cv2.cv2' has no attribute 'waitkey'

# %%
import cv2
from deepface import DeepFace
faceCascade = cv2.CascadeClassifier(cv2.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(1)
#check videocam is opened correctly
if not cap.isOpened():
    cap= cv2.VideoCapture(0)
if not   cap.isOpened():
    raise IOError("cannot open webcam")
    
while True :
    ret,frame = cap.read()#read one image from video
    result = DeepFace.analyze(frame, actions = ['emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    for (x, y, w, h) in faces:
        cv2.rectangle(img2, (x,y), (x+w, y+h), (0, 255, 0), 2)
   
    font = cv2.FONT_HERSHEY_SIMPLEX 
    cv2.putText(img,
            predictions['dominant_emotion'],
            (50,50),
            font, 3,
            (0, 0, 255),
            2,
            cv2.LINE_4
           );
    cv2.imshow('original video', frame)
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-b26e6fe19fbb> in <module>
#      11 while True :
#      12     ret,frame = cap.read()#read one image from video
# ---> 13     result = DeepFace.analyze(frame, actions = ['emotion'])
#      14
#      15     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#
# ~\anaconda34\envs\mvision\lib\site-packages\deepface\DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend)
#     422                         if action == 'emotion':
#     423                                 emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
# --> 424                                 img = functions.preprocess_face(img = img_path, target_size = (48, 48), grayscale = True, enforce_detection = enforce_detection, detector_backend = detector_backend)
#     425
#     426                                 emotion_predictions = emotion_model.predict(img)[0,:]
#
# ~\anaconda34\envs\mvision\lib\site-packages\deepface\commons\functions.py in preprocess_face(img, target_size, grayscale, enforce_detection, detector_backend)
#     453         base_img = img.copy()
#     454
# --> 455         img = detect_face(img = img, detector_backend = detector_backend, grayscale = grayscale, enforce_detection = enforce_detection)
#     456
#     457         #--------------------------
#
# ~\anaconda34\envs\mvision\lib\site-packages\deepface\commons\functions.py in detect_face(img, detector_backend, grayscale, enforce_detection)
#     160
#     161                         else:
# --> 162                                 raise ValueError("Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.")
#     163
#     164         elif detector_backend == 'ssd':
#
# ValueError: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.

# %%
import cv2
from deepface import DeepFace
faceCascade = cv2.CascadeClassifier(cv2.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(1)
#check videocam is opened correctly
if not cap.isOpened():
    cap= cv2.VideoCapture(0)
if not   cap.isOpened():
    raise IOError("cannot open webcam")
    
while True :
    ret,frame = cap.read()#read one image from video
    result = DeepFace.analyze(frame, actions = ['emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    for (x, y, w, h) in faces:
        cv2.rectangle(img2, (x,y), (x+w, y+h), (0, 255, 0), 2)
   
    font = cv2.FONT_HERSHEY_SIMPLEX 
    cv2.putText(img,
            predictions['dominant_emotion'],
            (50,50),
            font, 3,
            (0, 0, 255),
            2,
            cv2.LINE_4
           );
    cv2.imshow('original video', frame)
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()
# Out:
# Using TensorFlow backend.

# %%
import cv2
from deepface import DeepFace
faceCascade = cv2.CascadeClassifier(cv2.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(1)
#check videocam is opened correctly
if not cap.isOpened():
    cap= cv2.VideoCapture(0)
if not   cap.isOpened():
    raise IOError("cannot open webcam")
    
while True :
    ret,frame = cap.read()#read one image from video
    result = DeepFace.analyze(frame, actions = ['emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    for (x, y, w, h) in faces:
        cv2.rectangle(img2, (x,y), (x+w, y+h), (0, 255, 0), 2)
   
    font = cv2.FONT_HERSHEY_SIMPLEX 
    cv2.putText(img,
            predictions['dominant_emotion'],
            (50,50),
            font, 3,
            (0, 0, 255),
            2,
            cv2.LINE_4
           );
    cv2.imshow('original video', frame)
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b26e6fe19fbb> in <module>
#      16     faces = faceCascade.detectMultiScale(gray,1.1,4)
#      17     for (x, y, w, h) in faces:
# ---> 18         cv2.rectangle(img2, (x,y), (x+w, y+h), (0, 255, 0), 2)
#      19
#      20     font = cv2.FONT_HERSHEY_SIMPLEX
#
# NameError: name 'img2' is not defined

# %%
import cv2
from deepface import DeepFace
faceCascade = cv2.CascadeClassifier(cv2.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(1)
#check videocam is opened correctly
if not cap.isOpened():
    cap= cv2.VideoCapture(0)
if not   cap.isOpened():
    raise IOError("cannot open webcam")
    
while True :
    ret,frame = cap.read()#read one image from video
    result = DeepFace.analyze(frame, actions = ['emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x,y), (x+w, y+h), (0, 255, 0), 2)
   
    font = cv2.FONT_HERSHEY_SIMPLEX 
    cv2.putText(frame,
            result['dominant_emotion'],
            (50,50),
            font, 3,
            (0, 0, 255),
            2,
            cv2.LINE_4
           );
    cv2.imshow('original video', frame)
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()
